# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/WTAGRAPH/IEEE_SP_2022_WtaGraph/
# Out:
# /content/drive/MyDrive/WTAGRAPH/IEEE_SP_2022_WtaGraph

# %%
# !pip install --pre dgl -f https://data.dgl.ai/wheels/cu117/repo.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.dgl.ai/wheels/cu117/repo.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.5/266.5 MB 4.3 MB/s eta 0:00:00
# ...

# %%
# !python main.py --graph_name rand5k --gpu 0 --n-layers 1
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# Namespace(db_name='top10k', graph_name='rand5k', g_to_merge=None, dropout=0, gpu=0, lr=0.005, n_epochs=1000, n_hidden=16, n_layers=1, weight_decay=0.0005, r_train=0.8, r_test=0.1, testing_option=3, r_val=0.1, model_name='tmp_model_name', file_to_write='', fold=5, reduce_edge_feature=0)
#
# ************loading the specified graph and feature data************
# /usr/local/lib/python3.9/dist-packages/dgl/heterograph.py:72: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   dgl_warning('Recommend creating graphs by `dgl.graph(data)`'
# Loaded graph:  top10k rand5k Graph(num_nodes=30811, num_edges=787107,
#       ndata_schemes={}
#       edata_schemes={})
#
# ...

# %%
# !python main.py --graph_name rand5k --gpu 0 --n-layers 2
# Out:
# Namespace(db_name='top10k', graph_name='rand5k', g_to_merge=None, dropout=0, gpu=0, lr=0.005, n_epochs=1000, n_hidden=16, n_layers=2, weight_decay=0.0005, r_train=0.8, r_test=0.1, testing_option=3, r_val=0.1, model_name='tmp_model_name', file_to_write='', fold=5, reduce_edge_feature=0)
#
# ************loading the specified graph and feature data************
# /usr/local/lib/python3.9/dist-packages/dgl/heterograph.py:72: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   dgl_warning('Recommend creating graphs by `dgl.graph(data)`'
# Loaded graph:  top10k rand5k Graph(num_nodes=30811, num_edges=787107,
#       ndata_schemes={}
#       edata_schemes={})
#
# node feature shape: torch.Size([30811, 605])
# edge feature shape: torch.Size([787107, 3266])
# edge labels shape: torch.Size([787107])
# # of train edge: 629685    # of test edge: 78710  # of val edge: 78710
# ***************************loading completed***************************
#
#
# ...

# %%
# !python main.py --graph_name rand5k --gpu 0 --n-layers 1 --reduce_edge_feature 1
# Out:
# Namespace(db_name='top10k', graph_name='rand5k', g_to_merge=None, dropout=0, gpu=0, lr=0.005, n_epochs=1000, n_hidden=16, n_layers=1, weight_decay=0.0005, r_train=0.8, r_test=0.1, testing_option=3, r_val=0.1, model_name='tmp_model_name', file_to_write='', fold=5, reduce_edge_feature=1)
#
# ************loading the specified graph and feature data************
# /usr/local/lib/python3.9/dist-packages/dgl/heterograph.py:72: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   dgl_warning('Recommend creating graphs by `dgl.graph(data)`'
# Loaded graph:  top10k rand5k Graph(num_nodes=30811, num_edges=787107,
#       ndata_schemes={}
#       edata_schemes={})
#
# node feature shape: torch.Size([30811, 605])
# edge feature shape: torch.Size([787107, 1666])
# edge labels shape: torch.Size([787107])
# # of train edge: 629685    # of test edge: 78710  # of val edge: 78710
# ***************************loading completed***************************
#
#
# ...

# %%
# !python main.py --graph_name rand5k --gpu 0 --n-layers 2 --reduce_edge_feature 1
# Out:
# Namespace(db_name='top10k', graph_name='rand5k', g_to_merge=None, dropout=0, gpu=0, lr=0.005, n_epochs=1000, n_hidden=16, n_layers=2, weight_decay=0.0005, r_train=0.8, r_test=0.1, testing_option=3, r_val=0.1, model_name='tmp_model_name', file_to_write='', fold=5, reduce_edge_feature=1)
#
# ************loading the specified graph and feature data************
# /usr/local/lib/python3.9/dist-packages/dgl/heterograph.py:72: DGLWarning: Recommend creating graphs by `dgl.graph(data)` instead of `dgl.DGLGraph(data)`.
#   dgl_warning('Recommend creating graphs by `dgl.graph(data)`'
# Loaded graph:  top10k rand5k Graph(num_nodes=30811, num_edges=787107,
#       ndata_schemes={}
#       edata_schemes={})
#
# node feature shape: torch.Size([30811, 605])
# edge feature shape: torch.Size([787107, 1666])
# edge labels shape: torch.Size([787107])
# # of train edge: 629685    # of test edge: 78710  # of val edge: 78710
# ***************************loading completed***************************
#
#
# ...
